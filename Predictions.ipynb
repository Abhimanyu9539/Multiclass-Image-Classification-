# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
import os
import cv2
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt

# %%
# loads the model
model = tf.keras.models.load_model("model.h5")

# %%
def predictImage(filename):
    """
    loads image,resize them to 224*224
    """
    img1 = image.load_img(filename,target_size=(224,224))
    
    plt.imshow(img1)
 
    """converts image to numpy array"""
    Y = image.img_to_array(img1)
    
    """ add 4th dimentsion by expanding dims"""
    X = np.expand_dims(Y,axis=0)
    print(X.shape)
    val = np.argmax(model.predict(X))
    print(val)
    if val == 0:
        plt.xlabel("driving license",fontsize=30)
    elif val == 1:
        plt.xlabel("social security",fontsize=30)
    else:
        plt.xlabel("Others",fontsize=30)

# %%
predictImage("./Data/Testing_Data/others/101.jpg")
# Out:
# (1, 224, 224, 3)
# 2
